# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
geo_df = pd.read_csv('Geochemical data for assignment one.csv')

# %%
geo_df.head()
# Out:
#    Index       X        Y     Ti      V     Cr     Mn      Fe     Co     Ni  \
# 0      1  408391  9768300  0.698  0.354  0.241  2.447  88.197  0.889  0.845
# 1      2  408445  9768322  0.694  0.282  0.453  3.071  84.517  0.907  0.793
# 2      3  408486  9768324  0.554  0.323  0.291  3.225  86.295  0.811  0.736
# 3      4  408434  9768321  0.771  0.613  0.690  1.897  83.678  0.566  2.958
# 4      5  408583  9768317  0.679  0.685  0.603  2.285  83.841  0.697  2.901
#
#       Cu  Zn  Zr   Nb     Mo  Ag  Sn  Sb      W  Pb
# 0  2.826   0   0  0.0  1.295   0   0   0  0.661   0
# 1  4.674   0   0  0.0  1.857   0   0   0  0.456   0
# 2  3.502   0   0  0.0  1.419   0   0   0  0.681   0
# 3  3.130   0   0  0.0  0.300   0   0   0  0.984   0
# 4  2.952   0   0  0.0  0.271   0   0   0  0.995   0

# %%
geo_df.shape
# Out:
# (40, 20)

# %%
geo_df
# Out:
#     Index       X        Y     Ti      V     Cr     Mn      Fe     Co     Ni  \
# 0       1  408391  9768300  0.698  0.354  0.241  2.447  88.197  0.889  0.845
# 1       2  408445  9768322  0.694  0.282  0.453  3.071  84.517  0.907  0.793
# 2       3  408486  9768324  0.554  0.323  0.291  3.225  86.295  0.811  0.736
# 3       4  408434  9768321  0.771  0.613  0.690  1.897  83.678  0.566  2.958
# 4       5  408583  9768317  0.679  0.685  0.603  2.285  83.841  0.697  2.901
# 5       6  408594  9768263  0.408  0.823  0.448  0.631  86.757  0.109  2.073
# 6       7  408538  9768262  0.996  0.710  0.539  0.849  83.562  0.306  2.737
# 7       8  408497  9768248  0.542  0.017  0.267  0.400  96.073  0.000  0.988
# 8       9  408447  9768232  0.101  0.260  1.103  3.354  79.641  0.928  4.278
# 9      10  408397  9768222  0.500  0.652  1.828  4.244  73.289  1.498  5.509
# 10     11  408422  9768174  0.820  0.972  1.323  3.175  78.045  1.095  5.291
# ...

# %%
geo_df.set_index('Index', inplace=True)

# %%
geo_df.head()
# Out:
#             X        Y     Ti      V     Cr     Mn      Fe     Co     Ni  \
# Index
# 1      408391  9768300  0.698  0.354  0.241  2.447  88.197  0.889  0.845
# 2      408445  9768322  0.694  0.282  0.453  3.071  84.517  0.907  0.793
# 3      408486  9768324  0.554  0.323  0.291  3.225  86.295  0.811  0.736
# 4      408434  9768321  0.771  0.613  0.690  1.897  83.678  0.566  2.958
# 5      408583  9768317  0.679  0.685  0.603  2.285  83.841  0.697  2.901
#
#           Cu  Zn  Zr   Nb     Mo  Ag  Sn  Sb      W  Pb
# Index
# 1      2.826   0   0  0.0  1.295   0   0   0  0.661   0
# 2      4.674   0   0  0.0  1.857   0   0   0  0.456   0
# 3      3.502   0   0  0.0  1.419   0   0   0  0.681   0
# 4      3.130   0   0  0.0  0.300   0   0   0  0.984   0
# 5      2.952   0   0  0.0  0.271   0   0   0  0.995   0

# %%
geo_df.iloc[5]
# Out:
# X      408594.000
# Y     9768263.000
# Ti          0.408
# V           0.823
# Cr          0.448
# Mn          0.631
# Fe         86.757
# Co          0.109
# Ni          2.073
# Cu          1.977
# Zn          0.000
# Zr          0.000
# Nb          0.000
# Mo          0.146
# Ag          0.000
# Sn          0.000
# Sb          0.000
# W           0.976
# Pb          0.000
# Name: 6, dtype: float64

# %%
plt.plot(geo_df.index, geo_df['X'])

# %%
plt.plot(geo_df['X'], geo_df['Ti'])
